# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_model_optimization as tfmot
import tensorflow as tf
import os
import tempfile
from keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint

# %%
dataset = pd.read_excel('train_3rd_wrv_SNR45db.xlsx').values

# %%
train_percentage = 80
val_percentage = 20
def slice_dataset(dataset, percentage):
    data_size = len(dataset)
    index = [i for i in range (len(dataset))]
    np.random.shuffle(index)
    dataset_random = dataset[index,:]
    return dataset_random[:int(data_size*percentage/100)],dataset_random[int(data_size*percentage/100):]
train_dataset,val_dataset = slice_dataset(dataset, train_percentage)
X_train = np.expand_dims(train_dataset[:,0:5200].astype(float),axis =2)
Y_train = np.expand_dims(train_dataset[:,7000].astype(float),axis =1)
X_val = np.expand_dims(val_dataset[:,0:5200].astype(float),axis =2)
Y_val = np.expand_dims(val_dataset[:,7000].astype(float),axis =1)

# %%
f_input = 5200
f_output = 1
def setup_model():
    model = keras.Sequential([
        keras.layers.InputLayer(input_shape =(f_input,1)),
        keras.layers.Conv1D(filters=48, kernel_size=1,strides=1, padding="valid",activation='relu'),
        keras.layers.Conv1D(filters=48, kernel_size=1,strides=1, padding="valid",activation='relu'),
        keras.layers.Flatten(),
        #eras.layers.Reshape(target_shape=(99,1,1)),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.01),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(f_output, activation='linear'),
    ])
    return model

# %%
base_model = setup_model()
base_model.compile(optimizer = 'adam',
                 loss = 'mse',
                 metrics = ['mse'])
reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor = 0.5, patience=20, mode='auto')
log_filepath = os.path.join('log')
tb_cb = tf.keras.callbacks.TensorBoard(log_dir=log_filepath,histogram_freq=1)
history = base_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=200,batch_size=16,callbacks=[reduce_lr])
scores = base_model.evaluate(X_val, Y_val, verbose=0)
#model.save(os.path.join(log_filepath,'DNN_model.h5'))
print('%s: %.2f%%' % (base_model.metrics_names[1], scores[1] * 100))
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002E3805D8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002E3805D8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 55/55 [==============================] - ETA: 0s - loss: 3.4148 - mse: 3.4148WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002E342D96D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002E342D96D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 55/55 [==============================] - 5s 83ms/step - loss: 3.4148 - mse: 3.4148 - val_loss: 1.2380 - val_mse: 1.2380 - lr: 0.0010
# Epoch 2/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.7994 - mse: 0.7994 - val_loss: 0.9979 - val_mse: 0.9979 - lr: 0.0010
# Epoch 3/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.6225 - mse: 0.6225 - val_loss: 0.5750 - val_mse: 0.5750 - lr: 0.0010
# Epoch 4/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.4545 - mse: 0.4545 - val_loss: 0.4239 - val_mse: 0.4239 - lr: 0.0010
# Epoch 5/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.3015 - mse: 0.3015 - val_loss: 0.4309 - val_mse: 0.4309 - lr: 0.0010
# Epoch 6/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.2126 - mse: 0.2126 - val_loss: 0.2722 - val_mse: 0.2722 - lr: 0.0010
# Epoch 7/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.2173 - mse: 0.2173 - val_loss: 0.3981 - val_mse: 0.3981 - lr: 0.0010
# Epoch 8/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.1607 - mse: 0.1607 - val_loss: 0.3168 - val_mse: 0.3168 - lr: 0.0010
# Epoch 9/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.1464 - mse: 0.1464 - val_loss: 0.2566 - val_mse: 0.2566 - lr: 0.0010
# Epoch 10/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.1224 - mse: 0.1224 - val_loss: 0.2612 - val_mse: 0.2612 - lr: 0.0010
# Epoch 11/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.1096 - mse: 0.1096 - val_loss: 0.2294 - val_mse: 0.2294 - lr: 0.0010
# Epoch 12/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.2356 - val_mse: 0.2356 - lr: 0.0010
# Epoch 13/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0798 - mse: 0.0798 - val_loss: 0.1976 - val_mse: 0.1976 - lr: 0.0010
# Epoch 14/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0890 - mse: 0.0890 - val_loss: 0.2080 - val_mse: 0.2080 - lr: 0.0010
# Epoch 15/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0768 - mse: 0.0768 - val_loss: 0.2109 - val_mse: 0.2109 - lr: 0.0010
# Epoch 16/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0953 - mse: 0.0953 - val_loss: 0.2350 - val_mse: 0.2350 - lr: 0.0010
# Epoch 17/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.1980 - val_mse: 0.1980 - lr: 0.0010
# Epoch 18/200
# 55/55 [==============================] - 5s 85ms/step - loss: 0.0562 - mse: 0.0562 - val_loss: 0.1922 - val_mse: 0.1922 - lr: 0.0010
# Epoch 19/200
# 55/55 [==============================] - 5s 85ms/step - loss: 0.0548 - mse: 0.0548 - val_loss: 0.1877 - val_mse: 0.1877 - lr: 0.0010
# Epoch 20/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0623 - mse: 0.0623 - val_loss: 0.2247 - val_mse: 0.2247 - lr: 0.0010
# Epoch 21/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0594 - mse: 0.0594 - val_loss: 0.1961 - val_mse: 0.1961 - lr: 0.0010
# Epoch 22/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0344 - mse: 0.0344 - val_loss: 0.1791 - val_mse: 0.1791 - lr: 0.0010
# Epoch 23/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0370 - mse: 0.0370 - val_loss: 0.2225 - val_mse: 0.2225 - lr: 0.0010
# Epoch 24/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0449 - mse: 0.0449 - val_loss: 0.2154 - val_mse: 0.2154 - lr: 0.0010
# Epoch 25/200
# 55/55 [==============================] - 5s 85ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.2046 - val_mse: 0.2046 - lr: 0.0010
# Epoch 26/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.1978 - val_mse: 0.1978 - lr: 0.0010
# Epoch 27/200
# 55/55 [==============================] - 5s 85ms/step - loss: 0.0378 - mse: 0.0378 - val_loss: 0.2110 - val_mse: 0.2110 - lr: 0.0010
# Epoch 28/200
# 55/55 [==============================] - 5s 86ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.1753 - val_mse: 0.1753 - lr: 0.0010
# Epoch 29/200
# 55/55 [==============================] - 5s 87ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.1914 - val_mse: 0.1914 - lr: 0.0010
# Epoch 30/200
# 55/55 [==============================] - 5s 86ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.1875 - val_mse: 0.1875 - lr: 0.0010
# Epoch 31/200
# 55/55 [==============================] - 5s 85ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.1708 - val_mse: 0.1708 - lr: 0.0010
# Epoch 32/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.1903 - val_mse: 0.1903 - lr: 0.0010
# Epoch 33/200
# 55/55 [==============================] - 5s 87ms/step - loss: 0.0352 - mse: 0.0352 - val_loss: 0.2253 - val_mse: 0.2253 - lr: 0.0010
# Epoch 34/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.1693 - val_mse: 0.1693 - lr: 0.0010
# Epoch 35/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.1576 - val_mse: 0.1576 - lr: 0.0010
# Epoch 36/200
# 55/55 [==============================] - 5s 86ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.1746 - val_mse: 0.1746 - lr: 0.0010
# Epoch 37/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.1945 - val_mse: 0.1945 - lr: 0.0010
# Epoch 38/200
# 55/55 [==============================] - 5s 86ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.1859 - val_mse: 0.1859 - lr: 0.0010
# Epoch 39/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0355 - mse: 0.0355 - val_loss: 0.2005 - val_mse: 0.2005 - lr: 0.0010
# Epoch 40/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0460 - mse: 0.0460 - val_loss: 0.2120 - val_mse: 0.2120 - lr: 0.0010
# Epoch 41/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.1672 - val_mse: 0.1672 - lr: 0.0010
# Epoch 42/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0259 - mse: 0.0259 - val_loss: 0.1778 - val_mse: 0.1778 - lr: 0.0010
# Epoch 43/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.1996 - val_mse: 0.1996 - lr: 0.0010
# Epoch 44/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.2187 - val_mse: 0.2187 - lr: 0.0010
# Epoch 45/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 0.0010
# Epoch 46/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.1821 - val_mse: 0.1821 - lr: 0.0010
# Epoch 47/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.1793 - val_mse: 0.1793 - lr: 0.0010
# Epoch 48/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.1818 - val_mse: 0.1818 - lr: 0.0010
# Epoch 49/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.2059 - val_mse: 0.2059 - lr: 0.0010
# Epoch 50/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.1947 - val_mse: 0.1947 - lr: 0.0010
# Epoch 51/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.1793 - val_mse: 0.1793 - lr: 0.0010
# Epoch 52/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.1420 - val_mse: 0.1420 - lr: 0.0010
# Epoch 53/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.1587 - val_mse: 0.1587 - lr: 0.0010
# Epoch 54/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.1856 - val_mse: 0.1856 - lr: 0.0010
# Epoch 55/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0235 - mse: 0.0235 - val_loss: 0.1861 - val_mse: 0.1861 - lr: 0.0010
# Epoch 56/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0227 - mse: 0.0227 - val_loss: 0.1672 - val_mse: 0.1672 - lr: 0.0010
# Epoch 57/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.1649 - val_mse: 0.1649 - lr: 0.0010
# Epoch 58/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.1838 - val_mse: 0.1838 - lr: 0.0010
# Epoch 59/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.1679 - val_mse: 0.1679 - lr: 0.0010
# Epoch 60/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.1704 - val_mse: 0.1704 - lr: 0.0010
# Epoch 61/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.1834 - val_mse: 0.1834 - lr: 0.0010
# Epoch 62/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.1618 - val_mse: 0.1618 - lr: 0.0010
# Epoch 63/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.1796 - val_mse: 0.1796 - lr: 0.0010
# Epoch 64/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0293 - mse: 0.0293 - val_loss: 0.1514 - val_mse: 0.1514 - lr: 0.0010
# Epoch 65/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0262 - mse: 0.0262 - val_loss: 0.1797 - val_mse: 0.1797 - lr: 0.0010
# Epoch 66/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0323 - mse: 0.0323 - val_loss: 0.1689 - val_mse: 0.1689 - lr: 0.0010
# Epoch 67/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.1625 - val_mse: 0.1625 - lr: 0.0010
# Epoch 68/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0354 - mse: 0.0354 - val_loss: 0.1575 - val_mse: 0.1575 - lr: 0.0010
# Epoch 69/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0347 - mse: 0.0347 - val_loss: 0.2089 - val_mse: 0.2089 - lr: 0.0010
# Epoch 70/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0245 - mse: 0.0245 - val_loss: 0.1882 - val_mse: 0.1882 - lr: 0.0010
# Epoch 71/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.1848 - val_mse: 0.1848 - lr: 0.0010
# Epoch 72/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.1681 - val_mse: 0.1681 - lr: 0.0010
# Epoch 73/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.1596 - val_mse: 0.1596 - lr: 5.0000e-04
# Epoch 74/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.1592 - val_mse: 0.1592 - lr: 5.0000e-04
# Epoch 75/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.1705 - val_mse: 0.1705 - lr: 5.0000e-04
# Epoch 76/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.1685 - val_mse: 0.1685 - lr: 5.0000e-04
# Epoch 77/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.1591 - val_mse: 0.1591 - lr: 5.0000e-04
# Epoch 78/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.1587 - val_mse: 0.1587 - lr: 5.0000e-04
# Epoch 79/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.1597 - val_mse: 0.1597 - lr: 5.0000e-04
# Epoch 80/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.1620 - val_mse: 0.1620 - lr: 5.0000e-04
# Epoch 81/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.1697 - val_mse: 0.1697 - lr: 5.0000e-04
# Epoch 82/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.1763 - val_mse: 0.1763 - lr: 5.0000e-04
# Epoch 83/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.1596 - val_mse: 0.1596 - lr: 5.0000e-04
# Epoch 84/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.1779 - val_mse: 0.1779 - lr: 5.0000e-04
# Epoch 85/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.1618 - val_mse: 0.1618 - lr: 5.0000e-04
# Epoch 86/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.1612 - val_mse: 0.1612 - lr: 5.0000e-04
# Epoch 87/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.1642 - val_mse: 0.1642 - lr: 5.0000e-04
# Epoch 88/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.1662 - val_mse: 0.1662 - lr: 5.0000e-04
# Epoch 89/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.1630 - val_mse: 0.1630 - lr: 5.0000e-04
# Epoch 90/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.1642 - val_mse: 0.1642 - lr: 5.0000e-04
# Epoch 91/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.1699 - val_mse: 0.1699 - lr: 5.0000e-04
# Epoch 92/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.1675 - val_mse: 0.1675 - lr: 5.0000e-04
# Epoch 93/200
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.1728 - val_mse: 0.1728 - lr: 2.5000e-04
# Epoch 94/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.1633 - val_mse: 0.1633 - lr: 2.5000e-04
# Epoch 95/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.1628 - val_mse: 0.1628 - lr: 2.5000e-04
# Epoch 96/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.1567 - val_mse: 0.1567 - lr: 2.5000e-04
# Epoch 97/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 2.5000e-04
# Epoch 98/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.1672 - val_mse: 0.1672 - lr: 2.5000e-04
# Epoch 99/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.1631 - val_mse: 0.1631 - lr: 2.5000e-04
# Epoch 100/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.1613 - val_mse: 0.1613 - lr: 2.5000e-04
# Epoch 101/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.1622 - val_mse: 0.1622 - lr: 2.5000e-04
# Epoch 102/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.1635 - val_mse: 0.1635 - lr: 2.5000e-04
# Epoch 103/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.1635 - val_mse: 0.1635 - lr: 2.5000e-04
# Epoch 104/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.1597 - val_mse: 0.1597 - lr: 2.5000e-04
# Epoch 105/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.1568 - val_mse: 0.1568 - lr: 2.5000e-04
# Epoch 106/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.1778 - val_mse: 0.1778 - lr: 2.5000e-04
# Epoch 107/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.1603 - val_mse: 0.1603 - lr: 2.5000e-04
# Epoch 108/200
# 55/55 [==============================] - 4s 78ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.1665 - val_mse: 0.1665 - lr: 2.5000e-04
# Epoch 109/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.1613 - val_mse: 0.1613 - lr: 2.5000e-04
# Epoch 110/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.1635 - val_mse: 0.1635 - lr: 2.5000e-04
# Epoch 111/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.1763 - val_mse: 0.1763 - lr: 2.5000e-04
# Epoch 112/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.1590 - val_mse: 0.1590 - lr: 2.5000e-04
# Epoch 113/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.1612 - val_mse: 0.1612 - lr: 1.2500e-04
# Epoch 114/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.1595 - val_mse: 0.1595 - lr: 1.2500e-04
# Epoch 115/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.1570 - val_mse: 0.1570 - lr: 1.2500e-04
# Epoch 116/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.1605 - val_mse: 0.1605 - lr: 1.2500e-04
# Epoch 117/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.1573 - val_mse: 0.1573 - lr: 1.2500e-04
# Epoch 118/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.1602 - val_mse: 0.1602 - lr: 1.2500e-04
# Epoch 119/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.1610 - val_mse: 0.1610 - lr: 1.2500e-04
# Epoch 120/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.1610 - val_mse: 0.1610 - lr: 1.2500e-04
# Epoch 121/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.1595 - val_mse: 0.1595 - lr: 1.2500e-04
# Epoch 122/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.1582 - val_mse: 0.1582 - lr: 1.2500e-04
# Epoch 123/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1589 - val_mse: 0.1589 - lr: 1.2500e-04
# Epoch 124/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.1585 - val_mse: 0.1585 - lr: 1.2500e-04
# Epoch 125/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.1574 - val_mse: 0.1574 - lr: 1.2500e-04
# Epoch 126/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.1626 - val_mse: 0.1626 - lr: 1.2500e-04
# Epoch 127/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.1640 - val_mse: 0.1640 - lr: 1.2500e-04
# Epoch 128/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.1587 - val_mse: 0.1587 - lr: 1.2500e-04
# Epoch 129/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.1604 - val_mse: 0.1604 - lr: 1.2500e-04
# Epoch 130/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.1561 - val_mse: 0.1561 - lr: 1.2500e-04
# Epoch 131/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.1530 - val_mse: 0.1530 - lr: 1.2500e-04
# Epoch 132/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.1564 - val_mse: 0.1564 - lr: 1.2500e-04
# Epoch 133/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.1606 - val_mse: 0.1606 - lr: 6.2500e-05
# Epoch 134/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.1603 - val_mse: 0.1603 - lr: 6.2500e-05
# Epoch 135/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.1619 - val_mse: 0.1619 - lr: 6.2500e-05
# Epoch 136/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1583 - val_mse: 0.1583 - lr: 6.2500e-05
# Epoch 137/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.1580 - val_mse: 0.1580 - lr: 6.2500e-05
# Epoch 138/200
# 55/55 [==============================] - 4s 79ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1594 - val_mse: 0.1594 - lr: 6.2500e-05
# Epoch 139/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.1565 - val_mse: 0.1565 - lr: 6.2500e-05
# Epoch 140/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1607 - val_mse: 0.1607 - lr: 6.2500e-05
# Epoch 141/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1586 - val_mse: 0.1586 - lr: 6.2500e-05
# Epoch 142/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.1574 - val_mse: 0.1574 - lr: 6.2500e-05
# Epoch 143/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1629 - val_mse: 0.1629 - lr: 6.2500e-05
# Epoch 144/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.1601 - val_mse: 0.1601 - lr: 6.2500e-05
# Epoch 145/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1644 - val_mse: 0.1644 - lr: 6.2500e-05
# Epoch 146/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1572 - val_mse: 0.1572 - lr: 6.2500e-05
# Epoch 147/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1558 - val_mse: 0.1558 - lr: 6.2500e-05
# Epoch 148/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.1591 - val_mse: 0.1591 - lr: 6.2500e-05
# Epoch 149/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.1687 - val_mse: 0.1687 - lr: 6.2500e-05
# Epoch 150/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.1591 - val_mse: 0.1591 - lr: 6.2500e-05
# Epoch 151/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1604 - val_mse: 0.1604 - lr: 6.2500e-05
# Epoch 152/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.1556 - val_mse: 0.1556 - lr: 6.2500e-05
# Epoch 153/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1563 - val_mse: 0.1563 - lr: 3.1250e-05
# Epoch 154/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1604 - val_mse: 0.1604 - lr: 3.1250e-05
# Epoch 155/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1578 - val_mse: 0.1578 - lr: 3.1250e-05
# Epoch 156/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.1547 - val_mse: 0.1547 - lr: 3.1250e-05
# Epoch 157/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1600 - val_mse: 0.1600 - lr: 3.1250e-05
# Epoch 158/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1587 - val_mse: 0.1587 - lr: 3.1250e-05
# Epoch 159/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 3.1250e-05
# Epoch 160/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1614 - val_mse: 0.1614 - lr: 3.1250e-05
# Epoch 161/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1561 - val_mse: 0.1561 - lr: 3.1250e-05
# Epoch 162/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1592 - val_mse: 0.1592 - lr: 3.1250e-05
# Epoch 163/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1620 - val_mse: 0.1620 - lr: 3.1250e-05
# Epoch 164/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1557 - val_mse: 0.1557 - lr: 3.1250e-05
# Epoch 165/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1568 - val_mse: 0.1568 - lr: 3.1250e-05
# Epoch 166/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.1577 - val_mse: 0.1577 - lr: 3.1250e-05
# Epoch 167/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.1558 - val_mse: 0.1558 - lr: 3.1250e-05
# Epoch 168/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1604 - val_mse: 0.1604 - lr: 3.1250e-05
# Epoch 169/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.1598 - val_mse: 0.1598 - lr: 3.1250e-05
# Epoch 170/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.1621 - val_mse: 0.1621 - lr: 3.1250e-05
# Epoch 171/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1583 - val_mse: 0.1583 - lr: 3.1250e-05
# Epoch 172/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1619 - val_mse: 0.1619 - lr: 3.1250e-05
# Epoch 173/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1584 - val_mse: 0.1584 - lr: 1.5625e-05
# Epoch 174/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1588 - val_mse: 0.1588 - lr: 1.5625e-05
# Epoch 175/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1595 - val_mse: 0.1595 - lr: 1.5625e-05
# Epoch 176/200
# 55/55 [==============================] - 5s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1600 - val_mse: 0.1600 - lr: 1.5625e-05
# Epoch 177/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1589 - val_mse: 0.1589 - lr: 1.5625e-05
# Epoch 178/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1595 - val_mse: 0.1595 - lr: 1.5625e-05
# Epoch 179/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1587 - val_mse: 0.1587 - lr: 1.5625e-05
# Epoch 180/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1623 - val_mse: 0.1623 - lr: 1.5625e-05
# Epoch 181/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1593 - val_mse: 0.1593 - lr: 1.5625e-05
# Epoch 182/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1596 - val_mse: 0.1596 - lr: 1.5625e-05
# Epoch 183/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1608 - val_mse: 0.1608 - lr: 1.5625e-05
# Epoch 184/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 1.5625e-05
# Epoch 185/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.1586 - val_mse: 0.1586 - lr: 1.5625e-05
# Epoch 186/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1584 - val_mse: 0.1584 - lr: 1.5625e-05
# Epoch 187/200
# 55/55 [==============================] - 5s 84ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1579 - val_mse: 0.1579 - lr: 1.5625e-05
# Epoch 188/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 1.5625e-05
# Epoch 189/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1615 - val_mse: 0.1615 - lr: 1.5625e-05
# Epoch 190/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1602 - val_mse: 0.1602 - lr: 1.5625e-05
# Epoch 191/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1572 - val_mse: 0.1572 - lr: 1.5625e-05
# Epoch 192/200
# 55/55 [==============================] - 4s 82ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1589 - val_mse: 0.1589 - lr: 1.5625e-05
# Epoch 193/200
# 55/55 [==============================] - 4s 81ms/step - loss: 9.9964e-04 - mse: 9.9964e-04 - val_loss: 0.1620 - val_mse: 0.1620 - lr: 7.8125e-06
# Epoch 194/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1576 - val_mse: 0.1576 - lr: 7.8125e-06
# Epoch 195/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1581 - val_mse: 0.1581 - lr: 7.8125e-06
# Epoch 196/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1593 - val_mse: 0.1593 - lr: 7.8125e-06
# Epoch 197/200
# 55/55 [==============================] - 4s 80ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.1597 - val_mse: 0.1597 - lr: 7.8125e-06
# Epoch 198/200
# 55/55 [==============================] - 4s 81ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1594 - val_mse: 0.1594 - lr: 7.8125e-06
# Epoch 199/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.1586 - val_mse: 0.1586 - lr: 7.8125e-06
# Epoch 200/200
# 55/55 [==============================] - 5s 82ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1571 - val_mse: 0.1571 - lr: 7.8125e-06
# mse: 15.71%

# %%
from matplotlib import pyplot
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.yscale('log')
pyplot.legend()
pyplot.show()

# %%
predicted =base_model.predict(X_val)
#inverse_data1 = min_max_scaler.inverse_transform(predicted)
#inverse_data2 = min_max_scaler.inverse_transform(Y_test)
print(predicted[1])
print(Y_val[1].reshape(1))
ERR = []
for i in range(0,len(Y_val)):
    error=(predicted[i]-Y_val[i].reshape(1))
    ERR.append(error)
ERR=np.abs(np.array(ERR))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002E355C701F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002E355C701F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - 0s 25ms/step
# [5.9445295]
# [6.]

# %%
plt.xlabel('actual value of inertia(s)')
plt.ylabel('estimated values of inertia (s)')
plt.scatter(Y_val,predicted)
plt.savefig('Scatters_CNN_Delay_0.0.png',dpi=1000)
plt.show()

# %%
#print(ERR)
absvalues  = ERR.reshape(-1)
def acc(thre):
    Accuracy = np.sum(absvalues<=thre)/len(absvalues)
    return  Accuracy
print('\nTolerance=0.1: Accuracy=',  acc(0.1),
      '\nTolerance=0.2: Accuracy=',  acc(0.2),
      '\nTolerance=0.3: Accuracy=',  acc(0.3),
    '\nTolerance=0.4: Accuracy=', acc(0.4),'\nTolerance=0.5: Accuracy=',  acc(0.5))
# Out:
# Tolerance=0.1: Accuracy= 0.36363636363636365
# Tolerance=0.2: Accuracy= 0.5681818181818182
# Tolerance=0.3: Accuracy= 0.6909090909090909
# Tolerance=0.4: Accuracy= 0.7909090909090909
# Tolerance=0.5: Accuracy= 0.8318181818181818
