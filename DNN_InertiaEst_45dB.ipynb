# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_model_optimization as tfmot
import tensorflow as tf
import os
import tempfile
from keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint

# %%
dataset = pd.read_excel('train_3rd_wrv_SNR45db.xlsx').values

# %%
train_percentage = 80
val_percentage = 20
def slice_dataset(dataset, percentage):
    data_size = len(dataset)
    index = [i for i in range (len(dataset))]
    np.random.shuffle(index)
    dataset_random = dataset[index,:]
    return dataset_random[:int(data_size*percentage/100)],dataset_random[int(data_size*percentage/100):]
train_dataset,val_dataset = slice_dataset(dataset, train_percentage)
X_train = np.expand_dims(train_dataset[:,0:5200].astype(float),axis =2)
Y_train = np.expand_dims(train_dataset[:,7000].astype(float),axis =1)
X_val = np.expand_dims(val_dataset[:,0:5200].astype(float),axis =2)
Y_val = np.expand_dims(val_dataset[:,7000].astype(float),axis =1)

# %%
f_input = 5200
f_output = 1
def setup_model():
    model = keras.Sequential([
        keras.layers.InputLayer(input_shape =(f_input,1)),
        keras.layers.Flatten(),
        #eras.layers.Reshape(target_shape=(99,1,1)),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.01),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(f_output, activation='linear'),
    ])
    return model

# %%
base_model = setup_model()
base_model.compile(optimizer = 'adam',
                 loss = 'mse',
                 metrics = ['mse'])
reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor = 0.5, patience=20, mode='auto')
log_filepath = os.path.join('log')
tb_cb = tf.keras.callbacks.TensorBoard(log_dir=log_filepath,histogram_freq=1)
history = base_model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=200,batch_size=16,callbacks=[reduce_lr])
scores = base_model.evaluate(X_val, Y_val, verbose=0)
#model.save(os.path.join(log_filepath,'DNN_model.h5'))
print('%s: %.2f%%' % (base_model.metrics_names[1], scores[1] * 100))
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002550A1BD4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002550A1BD4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 52/55 [===========================>..] - ETA: 0s - loss: 2.9915 - mse: 2.9915WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000025505CA4948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000025505CA4948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 55/55 [==============================] - 2s 15ms/step - loss: 2.9069 - mse: 2.9069 - val_loss: 1.4677 - val_mse: 1.4677 - lr: 0.0010
# Epoch 2/200
# 55/55 [==============================] - 0s 9ms/step - loss: 1.2171 - mse: 1.2171 - val_loss: 0.5735 - val_mse: 0.5735 - lr: 0.0010
# Epoch 3/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6716 - mse: 0.6716 - val_loss: 0.4009 - val_mse: 0.4009 - lr: 0.0010
# Epoch 4/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.4983 - mse: 0.4983 - val_loss: 0.3400 - val_mse: 0.3400 - lr: 0.0010
# Epoch 5/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.4171 - mse: 0.4171 - val_loss: 0.3324 - val_mse: 0.3324 - lr: 0.0010
# Epoch 6/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3366 - mse: 0.3366 - val_loss: 0.3484 - val_mse: 0.3484 - lr: 0.0010
# Epoch 7/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.2948 - mse: 0.2948 - val_loss: 0.6102 - val_mse: 0.6102 - lr: 0.0010
# Epoch 8/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3622 - mse: 0.3622 - val_loss: 0.4298 - val_mse: 0.4298 - lr: 0.0010
# Epoch 9/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.2507 - mse: 0.2507 - val_loss: 0.2452 - val_mse: 0.2452 - lr: 0.0010
# Epoch 10/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.1832 - mse: 0.1832 - val_loss: 0.2719 - val_mse: 0.2719 - lr: 0.0010
# Epoch 11/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.2510 - val_mse: 0.2510 - lr: 0.0010
# Epoch 12/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.2490 - val_mse: 0.2490 - lr: 0.0010
# Epoch 13/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.1593 - mse: 0.1593 - val_loss: 0.2184 - val_mse: 0.2184 - lr: 0.0010
# Epoch 14/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1666 - mse: 0.1666 - val_loss: 0.3440 - val_mse: 0.3440 - lr: 0.0010
# Epoch 15/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1429 - mse: 0.1429 - val_loss: 0.2816 - val_mse: 0.2816 - lr: 0.0010
# Epoch 16/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.3444 - val_mse: 0.3444 - lr: 0.0010
# Epoch 17/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1669 - mse: 0.1669 - val_loss: 0.2611 - val_mse: 0.2611 - lr: 0.0010
# Epoch 18/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.1319 - mse: 0.1319 - val_loss: 0.2890 - val_mse: 0.2890 - lr: 0.0010
# Epoch 19/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.2068 - mse: 0.2068 - val_loss: 0.1915 - val_mse: 0.1915 - lr: 0.0010
# Epoch 20/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.2365 - mse: 0.2365 - val_loss: 0.4781 - val_mse: 0.4781 - lr: 0.0010
# Epoch 21/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.2003 - mse: 0.2003 - val_loss: 0.3657 - val_mse: 0.3657 - lr: 0.0010
# Epoch 22/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.2074 - mse: 0.2074 - val_loss: 0.2259 - val_mse: 0.2259 - lr: 0.0010
# Epoch 23/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.1026 - mse: 0.1026 - val_loss: 0.2060 - val_mse: 0.2060 - lr: 0.0010
# Epoch 24/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1071 - mse: 0.1071 - val_loss: 0.2431 - val_mse: 0.2431 - lr: 0.0010
# Epoch 25/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.1616 - mse: 0.1616 - val_loss: 0.2253 - val_mse: 0.2253 - lr: 0.0010
# Epoch 26/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0907 - mse: 0.0907 - val_loss: 0.1892 - val_mse: 0.1892 - lr: 0.0010
# Epoch 27/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.1901 - val_mse: 0.1901 - lr: 0.0010
# Epoch 28/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.1387 - mse: 0.1387 - val_loss: 0.5358 - val_mse: 0.5358 - lr: 0.0010
# Epoch 29/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.1170 - mse: 0.1170 - val_loss: 0.2026 - val_mse: 0.2026 - lr: 0.0010
# Epoch 30/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0677 - mse: 0.0677 - val_loss: 0.2030 - val_mse: 0.2030 - lr: 0.0010
# Epoch 31/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0676 - mse: 0.0676 - val_loss: 0.2259 - val_mse: 0.2259 - lr: 0.0010
# Epoch 32/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0713 - mse: 0.0713 - val_loss: 0.2265 - val_mse: 0.2265 - lr: 0.0010
# Epoch 33/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.2228 - val_mse: 0.2228 - lr: 0.0010
# Epoch 34/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.2002 - val_mse: 0.2002 - lr: 0.0010
# Epoch 35/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0801 - mse: 0.0801 - val_loss: 0.2021 - val_mse: 0.2021 - lr: 0.0010
# Epoch 36/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.1823 - val_mse: 0.1823 - lr: 0.0010
# Epoch 37/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0607 - mse: 0.0607 - val_loss: 0.1871 - val_mse: 0.1871 - lr: 0.0010
# Epoch 38/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0708 - mse: 0.0708 - val_loss: 0.2213 - val_mse: 0.2213 - lr: 0.0010
# Epoch 39/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.1855 - val_mse: 0.1855 - lr: 0.0010
# Epoch 40/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.1100 - mse: 0.1100 - val_loss: 0.2260 - val_mse: 0.2260 - lr: 0.0010
# Epoch 41/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0727 - mse: 0.0727 - val_loss: 0.1845 - val_mse: 0.1845 - lr: 0.0010
# Epoch 42/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0539 - mse: 0.0539 - val_loss: 0.1795 - val_mse: 0.1795 - lr: 0.0010
# Epoch 43/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.1495 - mse: 0.1495 - val_loss: 0.2578 - val_mse: 0.2578 - lr: 0.0010
# Epoch 44/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0586 - mse: 0.0586 - val_loss: 0.1798 - val_mse: 0.1798 - lr: 0.0010
# Epoch 45/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0576 - mse: 0.0576 - val_loss: 0.1877 - val_mse: 0.1877 - lr: 0.0010
# Epoch 46/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0517 - mse: 0.0517 - val_loss: 0.2340 - val_mse: 0.2340 - lr: 0.0010
# Epoch 47/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.1337 - mse: 0.1337 - val_loss: 0.1834 - val_mse: 0.1834 - lr: 0.0010
# Epoch 48/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.1780 - val_mse: 0.1780 - lr: 0.0010
# Epoch 49/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.2091 - val_mse: 0.2091 - lr: 0.0010
# Epoch 50/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0541 - mse: 0.0541 - val_loss: 0.2031 - val_mse: 0.2031 - lr: 0.0010
# Epoch 51/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0404 - mse: 0.0404 - val_loss: 0.1776 - val_mse: 0.1776 - lr: 0.0010
# Epoch 52/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0429 - mse: 0.0429 - val_loss: 0.1945 - val_mse: 0.1945 - lr: 0.0010
# Epoch 53/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0753 - mse: 0.0753 - val_loss: 0.1887 - val_mse: 0.1887 - lr: 0.0010
# Epoch 54/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.1741 - val_mse: 0.1741 - lr: 0.0010
# Epoch 55/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.3889 - val_mse: 0.3889 - lr: 0.0010
# Epoch 56/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0761 - mse: 0.0761 - val_loss: 0.2579 - val_mse: 0.2579 - lr: 0.0010
# Epoch 57/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0635 - mse: 0.0635 - val_loss: 0.2033 - val_mse: 0.2033 - lr: 0.0010
# Epoch 58/200
# 55/55 [==============================] - 1s 11ms/step - loss: 0.0392 - mse: 0.0392 - val_loss: 0.1828 - val_mse: 0.1828 - lr: 0.0010
# Epoch 59/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0467 - mse: 0.0467 - val_loss: 0.2072 - val_mse: 0.2072 - lr: 0.0010
# Epoch 60/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0805 - mse: 0.0805 - val_loss: 0.1842 - val_mse: 0.1842 - lr: 0.0010
# Epoch 61/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0498 - mse: 0.0498 - val_loss: 0.1928 - val_mse: 0.1928 - lr: 0.0010
# Epoch 62/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0615 - mse: 0.0615 - val_loss: 0.3114 - val_mse: 0.3114 - lr: 0.0010
# Epoch 63/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.1835 - val_mse: 0.1835 - lr: 0.0010
# Epoch 64/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0352 - mse: 0.0352 - val_loss: 0.1879 - val_mse: 0.1879 - lr: 0.0010
# Epoch 65/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0376 - mse: 0.0376 - val_loss: 0.1920 - val_mse: 0.1920 - lr: 0.0010
# Epoch 66/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.1757 - val_mse: 0.1757 - lr: 0.0010
# Epoch 67/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0478 - mse: 0.0478 - val_loss: 0.1937 - val_mse: 0.1937 - lr: 0.0010
# Epoch 68/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0472 - mse: 0.0472 - val_loss: 0.1766 - val_mse: 0.1766 - lr: 0.0010
# Epoch 69/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0357 - mse: 0.0357 - val_loss: 0.1936 - val_mse: 0.1936 - lr: 0.0010
# Epoch 70/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0611 - mse: 0.0611 - val_loss: 0.2039 - val_mse: 0.2039 - lr: 0.0010
# Epoch 71/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0648 - mse: 0.0648 - val_loss: 0.2224 - val_mse: 0.2224 - lr: 0.0010
# Epoch 72/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.2090 - val_mse: 0.2090 - lr: 0.0010
# Epoch 73/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0312 - mse: 0.0312 - val_loss: 0.2135 - val_mse: 0.2135 - lr: 0.0010
# Epoch 74/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0629 - mse: 0.0629 - val_loss: 0.2574 - val_mse: 0.2574 - lr: 0.0010
# Epoch 75/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.1880 - val_mse: 0.1880 - lr: 5.0000e-04
# Epoch 76/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.1774 - val_mse: 0.1774 - lr: 5.0000e-04
# Epoch 77/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.1688 - val_mse: 0.1688 - lr: 5.0000e-04
# Epoch 78/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.1682 - val_mse: 0.1682 - lr: 5.0000e-04
# Epoch 79/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.1668 - val_mse: 0.1668 - lr: 5.0000e-04
# Epoch 80/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.1726 - val_mse: 0.1726 - lr: 5.0000e-04
# Epoch 81/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.1736 - val_mse: 0.1736 - lr: 5.0000e-04
# Epoch 82/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.1693 - val_mse: 0.1693 - lr: 5.0000e-04
# Epoch 83/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.1676 - val_mse: 0.1676 - lr: 5.0000e-04
# Epoch 84/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.1756 - val_mse: 0.1756 - lr: 5.0000e-04
# Epoch 85/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.1706 - val_mse: 0.1706 - lr: 5.0000e-04
# Epoch 86/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.2009 - val_mse: 0.2009 - lr: 5.0000e-04
# Epoch 87/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0247 - mse: 0.0247 - val_loss: 0.1632 - val_mse: 0.1632 - lr: 5.0000e-04
# Epoch 88/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.1616 - val_mse: 0.1616 - lr: 5.0000e-04
# Epoch 89/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.1652 - val_mse: 0.1652 - lr: 5.0000e-04
# Epoch 90/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.1825 - val_mse: 0.1825 - lr: 5.0000e-04
# Epoch 91/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0246 - mse: 0.0246 - val_loss: 0.1609 - val_mse: 0.1609 - lr: 5.0000e-04
# Epoch 92/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.1606 - val_mse: 0.1606 - lr: 5.0000e-04
# Epoch 93/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.1707 - val_mse: 0.1707 - lr: 5.0000e-04
# Epoch 94/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.1920 - val_mse: 0.1920 - lr: 5.0000e-04
# Epoch 95/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0297 - mse: 0.0297 - val_loss: 0.2112 - val_mse: 0.2112 - lr: 5.0000e-04
# Epoch 96/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.2288 - val_mse: 0.2288 - lr: 5.0000e-04
# Epoch 97/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.1732 - val_mse: 0.1732 - lr: 5.0000e-04
# Epoch 98/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.1723 - val_mse: 0.1723 - lr: 5.0000e-04
# Epoch 99/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.1861 - val_mse: 0.1861 - lr: 5.0000e-04
# Epoch 100/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.1766 - val_mse: 0.1766 - lr: 5.0000e-04
# Epoch 101/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.1662 - val_mse: 0.1662 - lr: 5.0000e-04
# Epoch 102/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.1958 - val_mse: 0.1958 - lr: 5.0000e-04
# Epoch 103/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.1616 - val_mse: 0.1616 - lr: 5.0000e-04
# Epoch 104/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.1642 - val_mse: 0.1642 - lr: 5.0000e-04
# Epoch 105/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.1640 - val_mse: 0.1640 - lr: 5.0000e-04
# Epoch 106/200
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.1707 - val_mse: 0.1707 - lr: 5.0000e-04
# Epoch 107/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.1972 - val_mse: 0.1972 - lr: 5.0000e-04
# Epoch 108/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.1660 - val_mse: 0.1660 - lr: 5.0000e-04
# Epoch 109/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.1702 - val_mse: 0.1702 - lr: 5.0000e-04
# Epoch 110/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.1661 - val_mse: 0.1661 - lr: 5.0000e-04
# Epoch 111/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.1553 - val_mse: 0.1553 - lr: 5.0000e-04
# Epoch 112/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.1624 - val_mse: 0.1624 - lr: 5.0000e-04
# Epoch 113/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.1545 - val_mse: 0.1545 - lr: 5.0000e-04
# Epoch 114/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.1663 - val_mse: 0.1663 - lr: 5.0000e-04
# Epoch 115/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.1668 - val_mse: 0.1668 - lr: 5.0000e-04
# Epoch 116/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0237 - mse: 0.0237 - val_loss: 0.1778 - val_mse: 0.1778 - lr: 5.0000e-04
# Epoch 117/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.1620 - val_mse: 0.1620 - lr: 5.0000e-04
# Epoch 118/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.1831 - val_mse: 0.1831 - lr: 5.0000e-04
# Epoch 119/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.1646 - val_mse: 0.1646 - lr: 5.0000e-04
# Epoch 120/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.1757 - val_mse: 0.1757 - lr: 5.0000e-04
# Epoch 121/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.1644 - val_mse: 0.1644 - lr: 5.0000e-04
# Epoch 122/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 5.0000e-04
# Epoch 123/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.1675 - val_mse: 0.1675 - lr: 5.0000e-04
# Epoch 124/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.1749 - val_mse: 0.1749 - lr: 5.0000e-04
# Epoch 125/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.1593 - val_mse: 0.1593 - lr: 5.0000e-04
# Epoch 126/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.1760 - val_mse: 0.1760 - lr: 5.0000e-04
# Epoch 127/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.1663 - val_mse: 0.1663 - lr: 5.0000e-04
# Epoch 128/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.1936 - val_mse: 0.1936 - lr: 5.0000e-04
# Epoch 129/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.1638 - val_mse: 0.1638 - lr: 5.0000e-04
# Epoch 130/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.1633 - val_mse: 0.1633 - lr: 5.0000e-04
# Epoch 131/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0351 - mse: 0.0351 - val_loss: 0.1745 - val_mse: 0.1745 - lr: 5.0000e-04
# Epoch 132/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.1746 - val_mse: 0.1746 - lr: 5.0000e-04
# Epoch 133/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.1660 - val_mse: 0.1660 - lr: 5.0000e-04
# Epoch 134/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.1521 - val_mse: 0.1521 - lr: 2.5000e-04
# Epoch 135/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.1550 - val_mse: 0.1550 - lr: 2.5000e-04
# Epoch 136/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.1568 - val_mse: 0.1568 - lr: 2.5000e-04
# Epoch 137/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.1597 - val_mse: 0.1597 - lr: 2.5000e-04
# Epoch 138/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.1640 - val_mse: 0.1640 - lr: 2.5000e-04
# Epoch 139/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.1554 - val_mse: 0.1554 - lr: 2.5000e-04
# Epoch 140/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.1561 - val_mse: 0.1561 - lr: 2.5000e-04
# Epoch 141/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.1601 - val_mse: 0.1601 - lr: 2.5000e-04
# Epoch 142/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.1575 - val_mse: 0.1575 - lr: 2.5000e-04
# Epoch 143/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.1619 - val_mse: 0.1619 - lr: 2.5000e-04
# Epoch 144/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.1616 - val_mse: 0.1616 - lr: 2.5000e-04
# Epoch 145/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.1558 - val_mse: 0.1558 - lr: 2.5000e-04
# Epoch 146/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.1509 - val_mse: 0.1509 - lr: 2.5000e-04
# Epoch 147/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.1569 - val_mse: 0.1569 - lr: 2.5000e-04
# Epoch 148/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.1641 - val_mse: 0.1641 - lr: 2.5000e-04
# Epoch 149/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.1526 - val_mse: 0.1526 - lr: 2.5000e-04
# Epoch 150/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.1515 - val_mse: 0.1515 - lr: 2.5000e-04
# Epoch 151/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.1594 - val_mse: 0.1594 - lr: 2.5000e-04
# Epoch 152/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.1526 - val_mse: 0.1526 - lr: 2.5000e-04
# Epoch 153/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.1535 - val_mse: 0.1535 - lr: 2.5000e-04
# Epoch 154/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.1536 - val_mse: 0.1536 - lr: 2.5000e-04
# Epoch 155/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.1553 - val_mse: 0.1553 - lr: 2.5000e-04
# Epoch 156/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.1549 - val_mse: 0.1549 - lr: 2.5000e-04
# Epoch 157/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.1532 - val_mse: 0.1532 - lr: 2.5000e-04
# Epoch 158/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.1694 - val_mse: 0.1694 - lr: 2.5000e-04
# Epoch 159/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.1553 - val_mse: 0.1553 - lr: 2.5000e-04
# Epoch 160/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.1556 - val_mse: 0.1556 - lr: 2.5000e-04
# Epoch 161/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.1692 - val_mse: 0.1692 - lr: 2.5000e-04
# Epoch 162/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.1615 - val_mse: 0.1615 - lr: 2.5000e-04
# Epoch 163/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.1557 - val_mse: 0.1557 - lr: 2.5000e-04
# Epoch 164/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.1570 - val_mse: 0.1570 - lr: 2.5000e-04
# Epoch 165/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.1551 - val_mse: 0.1551 - lr: 2.5000e-04
# Epoch 166/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.1583 - val_mse: 0.1583 - lr: 2.5000e-04
# Epoch 167/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.1511 - val_mse: 0.1511 - lr: 1.2500e-04
# Epoch 168/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.1539 - val_mse: 0.1539 - lr: 1.2500e-04
# Epoch 169/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.1635 - val_mse: 0.1635 - lr: 1.2500e-04
# Epoch 170/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.1523 - val_mse: 0.1523 - lr: 1.2500e-04
# Epoch 171/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.1555 - val_mse: 0.1555 - lr: 1.2500e-04
# Epoch 172/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.1517 - val_mse: 0.1517 - lr: 1.2500e-04
# Epoch 173/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.1534 - val_mse: 0.1534 - lr: 1.2500e-04
# Epoch 174/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.1535 - val_mse: 0.1535 - lr: 1.2500e-04
# Epoch 175/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.1529 - val_mse: 0.1529 - lr: 1.2500e-04
# Epoch 176/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.1550 - val_mse: 0.1550 - lr: 1.2500e-04
# Epoch 177/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.1519 - val_mse: 0.1519 - lr: 1.2500e-04
# Epoch 178/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.1521 - val_mse: 0.1521 - lr: 1.2500e-04
# Epoch 179/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.1520 - val_mse: 0.1520 - lr: 1.2500e-04
# Epoch 180/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.1533 - val_mse: 0.1533 - lr: 1.2500e-04
# Epoch 181/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.1531 - val_mse: 0.1531 - lr: 1.2500e-04
# Epoch 182/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.1574 - val_mse: 0.1574 - lr: 1.2500e-04
# Epoch 183/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.1550 - val_mse: 0.1550 - lr: 1.2500e-04
# Epoch 184/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.1521 - val_mse: 0.1521 - lr: 1.2500e-04
# Epoch 185/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.1521 - val_mse: 0.1521 - lr: 1.2500e-04
# Epoch 186/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.1581 - val_mse: 0.1581 - lr: 1.2500e-04
# Epoch 187/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.1505 - val_mse: 0.1505 - lr: 6.2500e-05
# Epoch 188/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.1570 - val_mse: 0.1570 - lr: 6.2500e-05
# Epoch 189/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.1510 - val_mse: 0.1510 - lr: 6.2500e-05
# Epoch 190/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.1532 - val_mse: 0.1532 - lr: 6.2500e-05
# Epoch 191/200
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.1504 - val_mse: 0.1504 - lr: 6.2500e-05
# Epoch 192/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.1531 - val_mse: 0.1531 - lr: 6.2500e-05
# Epoch 193/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.1501 - val_mse: 0.1501 - lr: 6.2500e-05
# Epoch 194/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.1540 - val_mse: 0.1540 - lr: 6.2500e-05
# Epoch 195/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.1543 - val_mse: 0.1543 - lr: 6.2500e-05
# Epoch 196/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.1525 - val_mse: 0.1525 - lr: 6.2500e-05
# Epoch 197/200
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.1524 - val_mse: 0.1524 - lr: 6.2500e-05
# Epoch 198/200
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.1490 - val_mse: 0.1490 - lr: 6.2500e-05
# Epoch 199/200
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.1512 - val_mse: 0.1512 - lr: 6.2500e-05
# Epoch 200/200
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.1511 - val_mse: 0.1511 - lr: 6.2500e-05
# mse: 15.11%

# %%
from matplotlib import pyplot
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.yscale('log')
pyplot.legend()
pyplot.show()

# %%
predicted =base_model.predict(X_val)
#inverse_data1 = min_max_scaler.inverse_transform(predicted)
#inverse_data2 = min_max_scaler.inverse_transform(Y_test)
print(predicted[1])
print(Y_val[1].reshape(1))
ERR = []
for i in range(0,len(Y_val)):
    error=(predicted[i]-Y_val[i].reshape(1))
    ERR.append(error)
ERR=np.abs(np.array(ERR))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000025511361558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000025511361558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - 0s 6ms/step
# [5.3683157]
# [8.]

# %%
#print(ERR)
absvalues  = ERR.reshape(-1)
def acc(thre):
    Accuracy = np.sum(absvalues<=thre)/len(absvalues)
    return  Accuracy
print('\nTolerance=0.1: Accuracy=',  acc(0.1),
      '\nTolerance=0.2: Accuracy=',  acc(0.2),
      '\nTolerance=0.3: Accuracy=',  acc(0.3),
    '\nTolerance=0.4: Accuracy=', acc(0.4),'\nTolerance=0.5: Accuracy=',  acc(0.5))
# Out:
# Tolerance=0.1: Accuracy= 0.3181818181818182
# Tolerance=0.2: Accuracy= 0.5363636363636364
# Tolerance=0.3: Accuracy= 0.6863636363636364
# Tolerance=0.4: Accuracy= 0.8090909090909091
# Tolerance=0.5: Accuracy= 0.8954545454545455

# %%
#print(ERR)
percent  = ERR.reshape(-1)/Y_val.reshape(-1)
def acc(thre):
    Accuracy = np.sum(percent<=thre)/len(percent)
    return  Accuracy
print('\nTolerance=0.01: Accuracy=',  acc(0.01),
      '\nTolerance=0.02: Accuracy=',  acc(0.02),
      '\nTolerance=0.03: Accuracy=',  acc(0.03),
    '\nTolerance=0.04: Accuracy=', acc(0.04),'\nTolerance=0.05: Accuracy=',  acc(0.05)
     ,'\nTolerance=0.06: Accuracy=', acc(0.06),'\nTolerance=0.07: Accuracy=',  acc(0.07)
     ,'\nTolerance=0.08: Accuracy=', acc(0.08)
     ,'\nTolerance=0.09: Accuracy=', acc(0.09),'\nTolerance=0.10: Accuracy=',  acc(0.1))
# Out:
# Tolerance=0.01: Accuracy= 0.14545454545454545
# Tolerance=0.02: Accuracy= 0.3
# Tolerance=0.03: Accuracy= 0.4681818181818182
# Tolerance=0.04: Accuracy= 0.5636363636363636
# Tolerance=0.05: Accuracy= 0.6409090909090909
# Tolerance=0.06: Accuracy= 0.7363636363636363
# Tolerance=0.07: Accuracy= 0.8045454545454546
# Tolerance=0.08: Accuracy= 0.8590909090909091
# Tolerance=0.09: Accuracy= 0.8681818181818182
# Tolerance=0.10: Accuracy= 0.9090909090909091

# %%
plt.xlabel('Actual value of inertia(s)')
plt.ylabel('Estimated values of inertia (s)')
plt.scatter(Y_val,predicted)
plt.savefig('Scatters_DNN_Delay_0.0.png',dpi=1000)
plt.show()
